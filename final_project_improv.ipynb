# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import matplotlib.pyplot as plt
import numpy as np
from model import Net
from skimage.color import rgb2lab, lab2rgb
from torch.autograd import Variable

# scale to 256 * 256 then perform random crop to 224 * 224
transform_train = transforms.Compose([
    transforms.Resize(256),
    transforms.RandomCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor()
])

# scale to 224 * 224
transform_val = transforms.Compose([
    transforms.Resize(224),
    transforms.ToTensor()
])

class ColorizationDataset(datasets.ImageFolder):
    '''
    Custom Dataset for colorization
    '''
    def __getitem__(self, index):
        sample, target = super(ColorizationDataset, self).__getitem__(index)
        # color range L: [0,100], a&b: [-128, 127]
        lab = np.float32(rgb2lab(sample.permute(1, 2, 0)))
        l = lab[:, :, 0:1]
        # normalize a&b to [0, 1]
        ab = (lab[:, :, 1:] + 128) / 255
        return l, ab, target
    
class ColorizationDatasetCIFAR10(datasets.CIFAR10):
    '''
    Custom Dataset for colorization
    '''
    def __getitem__(self, index):
        sample, target = super(ColorizationDatasetCIFAR10, self).__getitem__(index)
        # color range L: [0,100], a&b: [-128, 127]
        lab = np.float32(rgb2lab(sample.permute(1, 2, 0)))
        l = lab[:, :, 0:1]
        # normalize a&b to [0, 1]
        ab = (lab[:, :, 1:] + 128) / 255
        return l, ab, target
    
data_root = '/home/shared/places365_standard'
train_dir = os.path.join(data_root, 'train')
train_set = ColorizationDataset(train_dir, transform=transform_train)
#train_set = ColorizationDatasetCIFAR10(root='./data', train=True, download=True, transform=transform_train)
train_loader = torch.utils.data.DataLoader(train_set, batch_size=128, shuffle=True, num_workers=4)

val_dir = os.path.join(data_root, 'val')
val_set = ColorizationDataset(val_dir, transform=transform_val)
#val_set = ColorizationDatasetCIFAR10(root='./data', train=False, download=True, transform=transform_val)
val_loader = torch.utils.data.DataLoader(val_set, batch_size=128, shuffle=False, num_workers=4)

def classificationLoss(outputs, labels):
    '''
    Calculate the cross-entropy loss for the classification network.
    The classification loss affects the low-level features network,
    global features network, and the classification network.
    '''
    return nn.CrossEntropyLoss()(outputs, labels)


def colorizationLoss(coloroutputs, colorlabels, classoutputs, classlabels):
    '''
    Calculate the loss for the colorization network.
    The colorization loss affects the entire network.
    '''
    # Choose an alpha so that the MSE loss and the cross-entropy loss
    # are similar in magnitude.
    alpha = 1.0 / 300 
    # Calculate the MSE loss for the colorization network
    colorLoss = nn.MSELoss()(coloroutputs, colorlabels)
    # Calculate the classification loss
    classLoss = classificationLoss(classoutputs, classlabels)
    # Calculate std loss
    stdLoss = 0.0001/coloroutputs[0,:,:,0].std() + 0.0001/coloroutputs[0,:,:,1].std()
    return colorLoss + alpha * classLoss + stdLoss


def train(train_loader, model, optimizer, use_gpu):
    '''
    Train both colorization and classification networks. 
    '''
    model.train()
    count = 0
    loss_sum = 0.0
    running_loss_sum = 0.0
    best_running_loss = float("inf")
    running_losses = []
    for i, (inputs, colors, labels) in enumerate(train_loader):
        if use_gpu:
            inputs, colors, labels = Variable(inputs.cuda()), Variable(colors.cuda()), Variable(labels.cuda())
        else:
            inputs = inputs.float()
            colors = colors.float()
        # predict and compute loss
        color_preds, label_preds = model(inputs)
        loss = colorizationLoss(color_preds, colors, label_preds, labels)
        
        # record loss
        loss_sum += loss.item()
        count += inputs.size(0)
        running_loss_sum += loss.item()
        
        # compute gradient and do Adadelta step for both colorization and classification networks.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # print statistics and save checkpoint
        step_size = 200
        if i % step_size == (step_size - 1):    # print every step_size mini-batches
            running_loss = running_loss_sum / step_size
            running_losses.append(running_loss)
            print('[%d, %5d] running loss: %.5f' % (epoch + 1, i + 1, running_loss))
            running_checkpoint = {
                'epoch': epoch + 1,
                'iteration': i,
                'running_losses': running_losses,
                'state_dict': model.state_dict(),
                'optimizer' : optimizer.state_dict()
            }
            # save the running checkpoint
            if running_loss < best_running_loss:
                best_running_loss = running_loss
                # save the best running checkpoint
                print('Saving the new best running checkpoint')
                save_checkpoint(running_checkpoint, 'best_running_checkpoint_improv.pth.tar')
            print('Saving the new running checkpoint')
            save_checkpoint(running_checkpoint, 'running_checkpoint_improv.pth.tar')
            running_loss_sum = 0.0
            
    return loss_sum / count
        
def validate(val_loader, model, use_gpu):
    '''
    Evaluate both colorization and classification networks.
    '''
    model.eval()
    count = 0
    loss_sum = 0.0
    with torch.no_grad():
        for i, (inputs, colors, labels) in enumerate(val_loader):
            if use_gpu:
                inputs, colors, labels = Variable(inputs.cuda()), Variable(colors.cuda()), Variable(labels.cuda())
            else:
                inputs = inputs.float()
                colors = colors.float()
            # predict and compute losses
            color_preds, label_preds = model(inputs)
            loss = colorizationLoss(color_preds, colors, label_preds, labels)
            
            # record loss
            loss_sum += loss.item()
            count += inputs.size(0)
    
    return loss_sum / count


def save_checkpoint(state, filename='checkpoint_improv.pth.tar'):
    '''
    Save checkpoint for the given state. 
    '''
    torch.save(state, filename)

def load_checkpoint(filename='checkpoint_improv.pth.tar'):
    '''
    Load checkpoint from file. 
    '''
    if os.path.isfile(filename):
        return torch.load(filename)
    else:
        return None
    
# Checking GPU availability
use_gpu = torch.cuda.is_available()

# Initialize model and optimizer
model = Net()
if use_gpu:
    model = model.cuda()
    print('Use GPU')
else:
    print('Use CPU')
# Use ADADELTA optimizer    
optimizer = optim.Adadelta(model.parameters(), lr=1)
start_epoch = 0
total_epochs = 20
best_loss = float("inf")
train_losses = []
val_losses = []
# Load from checkpoint if exists
checkpoint = load_checkpoint()
if checkpoint:
    start_epoch = checkpoint['epoch']
    train_losses = checkpoint['train_losses']
    val_losses = checkpoint['val_losses']
    best_loss = min(val_losses)
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    print('Loaded checkpoint from epoch %d' % start_epoch)
for epoch in range(start_epoch, total_epochs):
    print('Start training for epoch %d' % (epoch + 1))
    # train for one epoch
    train_loss = train(train_loader, model, optimizer, use_gpu)
    train_losses.append(train_loss)
    print('Training loss for epoch %d: %.5f' % (epoch + 1, train_loss))
    
    # evaluate on validation set
    print('Start validation for epoch %d' % (epoch + 1))
    val_loss = validate(val_loader, model, use_gpu)
    val_losses.append(val_loss)
    print('Validation loss for epoch %d: %.5f' % (epoch + 1, val_loss))
    
    new_checkpoint = {
        'epoch': epoch + 1,
        'train_losses': train_losses,
        'val_losses': val_losses,
        'state_dict': model.state_dict(),
        'optimizer' : optimizer.state_dict()
    }
    if val_loss < best_loss:
        best_loss = val_loss
        # save the best checkpoint
        print('Saving the new best checkpoint')
        save_checkpoint(new_checkpoint, 'best_checkpoint_improv.pth.tar')
    # save checkpoint
    print('Saving the checkpoint for epoch %d' % (epoch + 1))
    save_checkpoint(new_checkpoint)
    save_checkpoint(new_checkpoint, 'checkpoint%d_improv.pth.tar' % (epoch + 1))
# Out:
# Use GPU
# Loaded checkpoint from epoch 11
# Start training for epoch 12
# [12,   200] running loss: 0.01549
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [12,   400] running loss: 0.01555
# Saving the new running checkpoint
# [12,   600] running loss: 0.01548
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [12,   800] running loss: 0.01547
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [12,  1000] running loss: 0.01546
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [12,  1200] running loss: 0.01547
# Saving the new running checkpoint
# [12,  1400] running loss: 0.01555
# Saving the new running checkpoint
# [12,  1600] running loss: 0.01558
# Saving the new running checkpoint
# [12,  1800] running loss: 0.01544
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [12,  2000] running loss: 0.01554
# Saving the new running checkpoint
# [12,  2200] running loss: 0.01537
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [12,  2400] running loss: 0.01546
# Saving the new running checkpoint
# [12,  2600] running loss: 0.01542
# Saving the new running checkpoint
# [12,  2800] running loss: 0.01549
# Saving the new running checkpoint
# [12,  3000] running loss: 0.01555
# Saving the new running checkpoint
# [12,  3200] running loss: 0.01557
# Saving the new running checkpoint
# [12,  3400] running loss: 0.01548
# Saving the new running checkpoint
# [12,  3600] running loss: 0.01534
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [12,  3800] running loss: 0.01550
# Saving the new running checkpoint
# [12,  4000] running loss: 0.01538
# Saving the new running checkpoint
# [12,  4200] running loss: 0.01531
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [12,  4400] running loss: 0.01548
# Saving the new running checkpoint
# [12,  4600] running loss: 0.01554
# Saving the new running checkpoint
# [12,  4800] running loss: 0.01536
# Saving the new running checkpoint
# [12,  5000] running loss: 0.01546
# Saving the new running checkpoint
# [12,  5200] running loss: 0.01542
# Saving the new running checkpoint
# [12,  5400] running loss: 0.01550
# Saving the new running checkpoint
# [12,  5600] running loss: 0.01545
# Saving the new running checkpoint
# [12,  5800] running loss: 0.01545
# Saving the new running checkpoint
# [12,  6000] running loss: 0.01546
# Saving the new running checkpoint
# [12,  6200] running loss: 0.01542
# Saving the new running checkpoint
# [12,  6400] running loss: 0.01550
# Saving the new running checkpoint
# [12,  6600] running loss: 0.01539
# Saving the new running checkpoint
# [12,  6800] running loss: 0.01538
# Saving the new running checkpoint
# [12,  7000] running loss: 0.01552
# Saving the new running checkpoint
# [12,  7200] running loss: 0.01542
# Saving the new running checkpoint
# [12,  7400] running loss: 0.01537
# Saving the new running checkpoint
# [12,  7600] running loss: 0.01537
# Saving the new running checkpoint
# [12,  7800] running loss: 0.01543
# Saving the new running checkpoint
# [12,  8000] running loss: 0.01539
# Saving the new running checkpoint
# [12,  8200] running loss: 0.01544
# Saving the new running checkpoint
# [12,  8400] running loss: 0.01542
# Saving the new running checkpoint
# [12,  8600] running loss: 0.01554
# Saving the new running checkpoint
# [12,  8800] running loss: 0.01542
# Saving the new running checkpoint
# [12,  9000] running loss: 0.01546
# Saving the new running checkpoint
# [12,  9200] running loss: 0.01535
# Saving the new running checkpoint
# [12,  9400] running loss: 0.01554
# Saving the new running checkpoint
# [12,  9600] running loss: 0.01542
# Saving the new running checkpoint
# [12,  9800] running loss: 0.01543
# Saving the new running checkpoint
# [12, 10000] running loss: 0.01542
# Saving the new running checkpoint
# [12, 10200] running loss: 0.01546
# Saving the new running checkpoint
# [12, 10400] running loss: 0.01544
# Saving the new running checkpoint
# [12, 10600] running loss: 0.01541
# Saving the new running checkpoint
# [12, 10800] running loss: 0.01551
# Saving the new running checkpoint
# [12, 11000] running loss: 0.01536
# Saving the new running checkpoint
# [12, 11200] running loss: 0.01539
# Saving the new running checkpoint
# [12, 11400] running loss: 0.01540
# Saving the new running checkpoint
# [12, 11600] running loss: 0.01546
# Saving the new running checkpoint
# [12, 11800] running loss: 0.01536
# Saving the new running checkpoint
# [12, 12000] running loss: 0.01546
# Saving the new running checkpoint
# [12, 12200] running loss: 0.01550
# Saving the new running checkpoint
# [12, 12400] running loss: 0.01550
# Saving the new running checkpoint
# [12, 12600] running loss: 0.01536
# Saving the new running checkpoint
# [12, 12800] running loss: 0.01554
# Saving the new running checkpoint
# [12, 13000] running loss: 0.01531
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [12, 13200] running loss: 0.01531
# Saving the new running checkpoint
# [12, 13400] running loss: 0.01538
# Saving the new running checkpoint
# [12, 13600] running loss: 0.01547
# Saving the new running checkpoint
# [12, 13800] running loss: 0.01534
# Saving the new running checkpoint
# [12, 14000] running loss: 0.01542
# Saving the new running checkpoint
# Training loss for epoch 12: 0.00012
# Start validation for epoch 12
# Validation loss for epoch 12: 0.00012
# Saving the new best checkpoint
# Saving the checkpoint for epoch 12
# Start training for epoch 13
# [13,   200] running loss: 0.01532
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [13,   400] running loss: 0.01538
# Saving the new running checkpoint
# [13,   600] running loss: 0.01537
# Saving the new running checkpoint
# [13,   800] running loss: 0.01532
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [13,  1000] running loss: 0.01520
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [13,  1200] running loss: 0.01524
# Saving the new running checkpoint
# [13,  1400] running loss: 0.01534
# Saving the new running checkpoint
# [13,  1600] running loss: 0.01531
# Saving the new running checkpoint
# [13,  1800] running loss: 0.01540
# Saving the new running checkpoint
# [13,  2000] running loss: 0.01525
# Saving the new running checkpoint
# [13,  2200] running loss: 0.01535
# Saving the new running checkpoint
# [13,  2400] running loss: 0.01526
# Saving the new running checkpoint
# [13,  2600] running loss: 0.01528
# Saving the new running checkpoint
# [13,  2800] running loss: 0.01532
# Saving the new running checkpoint
# [13,  3000] running loss: 0.01533
# Saving the new running checkpoint
# [13,  3200] running loss: 0.01535
# Saving the new running checkpoint
# [13,  3400] running loss: 0.01526
# Saving the new running checkpoint
# [13,  3600] running loss: 0.01533
# Saving the new running checkpoint
# [13,  3800] running loss: 0.01523
# Saving the new running checkpoint
# [13,  4000] running loss: 0.01538
# Saving the new running checkpoint
# [13,  4200] running loss: 0.01537
# Saving the new running checkpoint
# [13,  4400] running loss: 0.01533
# Saving the new running checkpoint
# [13,  4600] running loss: 0.01535
# Saving the new running checkpoint
# [13,  4800] running loss: 0.01525
# Saving the new running checkpoint
# [13,  5000] running loss: 0.01539
# Saving the new running checkpoint
# [13,  5200] running loss: 0.01535
# Saving the new running checkpoint
# [13,  5400] running loss: 0.01529
# Saving the new running checkpoint
# [13,  5600] running loss: 0.01534
# Saving the new running checkpoint
# [13,  5800] running loss: 0.01537
# Saving the new running checkpoint
# [13,  6000] running loss: 0.01526
# Saving the new running checkpoint
# [13,  6200] running loss: 0.01527
# Saving the new running checkpoint
# [13,  6400] running loss: 0.01539
# Saving the new running checkpoint
# [13,  6600] running loss: 0.01521
# Saving the new running checkpoint
# [13,  6800] running loss: 0.01543
# Saving the new running checkpoint
# [13,  7000] running loss: 0.01534
# Saving the new running checkpoint
# [13,  7200] running loss: 0.01528
# Saving the new running checkpoint
# [13,  7400] running loss: 0.01519
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [13,  7600] running loss: 0.01521
# Saving the new running checkpoint
# [13,  7800] running loss: 0.01533
# Saving the new running checkpoint
# [13,  8000] running loss: 0.01530
# Saving the new running checkpoint
# [13,  8200] running loss: 0.01530
# Saving the new running checkpoint
# [13,  8400] running loss: 0.01524
# Saving the new running checkpoint
# [13,  8600] running loss: 0.01523
# Saving the new running checkpoint
# [13,  8800] running loss: 0.01529
# Saving the new running checkpoint
# [13,  9000] running loss: 0.01527
# Saving the new running checkpoint
# [13,  9200] running loss: 0.01519
# Saving the new running checkpoint
# [13,  9400] running loss: 0.01520
# Saving the new running checkpoint
# [13,  9600] running loss: 0.01528
# Saving the new running checkpoint
# [13,  9800] running loss: 0.01540
# Saving the new running checkpoint
# [13, 10000] running loss: 0.01522
# Saving the new running checkpoint
# [13, 10200] running loss: 0.01533
# Saving the new running checkpoint
# [13, 10400] running loss: 0.01537
# Saving the new running checkpoint
# [13, 10600] running loss: 0.01532
# Saving the new running checkpoint
# [13, 10800] running loss: 0.01525
# Saving the new running checkpoint
# [13, 11000] running loss: 0.01530
# Saving the new running checkpoint
# [13, 11200] running loss: 0.01522
# Saving the new running checkpoint
# [13, 11400] running loss: 0.01523
# Saving the new running checkpoint
# [13, 11600] running loss: 0.01524
# Saving the new running checkpoint
# [13, 11800] running loss: 0.01524
# Saving the new running checkpoint
# [13, 12000] running loss: 0.01520
# Saving the new running checkpoint
# [13, 12200] running loss: 0.01516
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [13, 12400] running loss: 0.01534
# Saving the new running checkpoint
# [13, 12600] running loss: 0.01515
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [13, 12800] running loss: 0.01520
# Saving the new running checkpoint
# [13, 13000] running loss: 0.01529
# Saving the new running checkpoint
# [13, 13200] running loss: 0.01532
# Saving the new running checkpoint
# [13, 13400] running loss: 0.01524
# Saving the new running checkpoint
# [13, 13600] running loss: 0.01526
# Saving the new running checkpoint
# [13, 13800] running loss: 0.01525
# Saving the new running checkpoint
# [13, 14000] running loss: 0.01526
# Saving the new running checkpoint
# Training loss for epoch 13: 0.00012
# Start validation for epoch 13
# Validation loss for epoch 13: 0.00013
# Saving the checkpoint for epoch 13
# Start training for epoch 14
# [14,   200] running loss: 0.01514
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [14,   400] running loss: 0.01527
# Saving the new running checkpoint
# [14,   600] running loss: 0.01504
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [14,   800] running loss: 0.01513
# Saving the new running checkpoint
# [14,  1000] running loss: 0.01521
# Saving the new running checkpoint
# [14,  1200] running loss: 0.01518
# Saving the new running checkpoint
# [14,  1400] running loss: 0.01516
# Saving the new running checkpoint
# [14,  1600] running loss: 0.01507
# Saving the new running checkpoint
# [14,  1800] running loss: 0.01525
# Saving the new running checkpoint
# [14,  2000] running loss: 0.01506
# Saving the new running checkpoint
# [14,  2200] running loss: 0.01527
# Saving the new running checkpoint
# [14,  2400] running loss: 0.01520
# Saving the new running checkpoint
# [14,  2600] running loss: 0.01522
# Saving the new running checkpoint
# [14,  2800] running loss: 0.01527
# Saving the new running checkpoint
# [14,  3000] running loss: 0.01521
# Saving the new running checkpoint
# [14,  3200] running loss: 0.01507
# Saving the new running checkpoint
# [14,  3400] running loss: 0.01524
# Saving the new running checkpoint
# [14,  3600] running loss: 0.01519
# Saving the new running checkpoint
# [14,  3800] running loss: 0.01515
# Saving the new running checkpoint
# [14,  4000] running loss: 0.01524
# Saving the new running checkpoint
# [14,  4200] running loss: 0.01511
# Saving the new running checkpoint
# [14,  4400] running loss: 0.01517
# Saving the new running checkpoint
# [14,  4600] running loss: 0.01523
# Saving the new running checkpoint
# [14,  4800] running loss: 0.01518
# Saving the new running checkpoint
# [14,  5000] running loss: 0.01521
# Saving the new running checkpoint
# [14,  5200] running loss: 0.01517
# Saving the new running checkpoint
# [14,  5400] running loss: 0.01516
# Saving the new running checkpoint
# [14,  5600] running loss: 0.01516
# Saving the new running checkpoint
# [14,  5800] running loss: 0.01506
# Saving the new running checkpoint
# [14,  6000] running loss: 0.01517
# Saving the new running checkpoint
# [14,  6200] running loss: 0.01528
# Saving the new running checkpoint
# [14,  6400] running loss: 0.01538
# Saving the new running checkpoint
# [14,  6600] running loss: 0.01508
# Saving the new running checkpoint
# [14,  6800] running loss: 0.01518
# Saving the new running checkpoint
# [14,  7000] running loss: 0.01512
# Saving the new running checkpoint
# [14,  7200] running loss: 0.01510
# Saving the new running checkpoint
# [14,  7400] running loss: 0.01507
# Saving the new running checkpoint
# [14,  7600] running loss: 0.01510
# Saving the new running checkpoint
# [14,  7800] running loss: 0.01522
# Saving the new running checkpoint
# [14,  8000] running loss: 0.01517
# Saving the new running checkpoint
# [14,  8200] running loss: 0.01509
# Saving the new running checkpoint
# [14,  8400] running loss: 0.01512
# Saving the new running checkpoint
# [14,  8600] running loss: 0.01517
# Saving the new running checkpoint
# [14,  8800] running loss: 0.01511
# Saving the new running checkpoint
# [14,  9000] running loss: 0.01513
# Saving the new running checkpoint
# [14,  9200] running loss: 0.01525
# Saving the new running checkpoint
# [14,  9400] running loss: 0.01517
# Saving the new running checkpoint
# [14,  9600] running loss: 0.01522
# Saving the new running checkpoint
# [14,  9800] running loss: 0.01516
# Saving the new running checkpoint
# [14, 10000] running loss: 0.01518
# Saving the new running checkpoint
# [14, 10200] running loss: 0.01519
# Saving the new running checkpoint
# [14, 10400] running loss: 0.01515
# Saving the new running checkpoint
# [14, 10600] running loss: 0.01514
# Saving the new running checkpoint
# [14, 10800] running loss: 0.01508
# Saving the new running checkpoint
# [14, 11000] running loss: 0.01510
# Saving the new running checkpoint
# [14, 11200] running loss: 0.01513
# Saving the new running checkpoint
# [14, 11400] running loss: 0.01508
# Saving the new running checkpoint
# [14, 11600] running loss: 0.01514
# Saving the new running checkpoint
# [14, 11800] running loss: 0.01522
# Saving the new running checkpoint
# [14, 12000] running loss: 0.01501
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [14, 12200] running loss: 0.01519
# Saving the new running checkpoint
# [14, 12400] running loss: 0.01516
# Saving the new running checkpoint
# [14, 12600] running loss: 0.01509
# Saving the new running checkpoint
# [14, 12800] running loss: 0.01512
# Saving the new running checkpoint
# [14, 13000] running loss: 0.01517
# Saving the new running checkpoint
# [14, 13200] running loss: 0.01502
# Saving the new running checkpoint
# [14, 13400] running loss: 0.01511
# Saving the new running checkpoint
# [14, 13600] running loss: 0.01507
# Saving the new running checkpoint
# [14, 13800] running loss: 0.01518
# Saving the new running checkpoint
# [14, 14000] running loss: 0.01512
# Saving the new running checkpoint
# Training loss for epoch 14: 0.00012
# Start validation for epoch 14
# Validation loss for epoch 14: 0.00013
# Saving the checkpoint for epoch 14
# Start training for epoch 15
# [15,   200] running loss: 0.01502
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [15,   400] running loss: 0.01503
# Saving the new running checkpoint
# [15,   600] running loss: 0.01503
# Saving the new running checkpoint
# [15,   800] running loss: 0.01503
# Saving the new running checkpoint
# [15,  1000] running loss: 0.01499
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [15,  1200] running loss: 0.01506
# Saving the new running checkpoint
# [15,  1400] running loss: 0.01512
# Saving the new running checkpoint
# [15,  1600] running loss: 0.01503
# Saving the new running checkpoint
# [15,  1800] running loss: 0.01501
# Saving the new running checkpoint
# [15,  2000] running loss: 0.01506
# Saving the new running checkpoint
# [15,  2200] running loss: 0.01513
# Saving the new running checkpoint
# [15,  2400] running loss: 0.01507
# Saving the new running checkpoint
# [15,  2600] running loss: 0.01502
# Saving the new running checkpoint
# [15,  2800] running loss: 0.01497
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [15,  3000] running loss: 0.01508
# Saving the new running checkpoint
# [15,  3200] running loss: 0.01507
# Saving the new running checkpoint
# [15,  3400] running loss: 0.01504
# Saving the new running checkpoint
# [15,  3600] running loss: 0.01501
# Saving the new running checkpoint
# [15,  3800] running loss: 0.01499
# Saving the new running checkpoint
# [15,  4000] running loss: 0.01515
# Saving the new running checkpoint
# [15,  4200] running loss: 0.01500
# Saving the new running checkpoint
# [15,  4400] running loss: 0.01496
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [15,  4600] running loss: 0.01503
# Saving the new running checkpoint
# [15,  4800] running loss: 0.01499
# Saving the new running checkpoint
# [15,  5000] running loss: 0.01500
# Saving the new running checkpoint
# [15,  5200] running loss: 0.01504
# Saving the new running checkpoint
# [15,  5400] running loss: 0.01500
# Saving the new running checkpoint
# [15,  5600] running loss: 0.01504
# Saving the new running checkpoint
# [15,  5800] running loss: 0.01507
# Saving the new running checkpoint
# [15,  6000] running loss: 0.01504
# Saving the new running checkpoint
# [15,  6200] running loss: 0.01507
# Saving the new running checkpoint
# [15,  6400] running loss: 0.01506
# Saving the new running checkpoint
# [15,  6600] running loss: 0.01508
# Saving the new running checkpoint
# [15,  6800] running loss: 0.01511
# Saving the new running checkpoint
# [15,  7000] running loss: 0.01500
# Saving the new running checkpoint
# [15,  7200] running loss: 0.01492
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [15,  7400] running loss: 0.01509
# Saving the new running checkpoint
# [15,  7600] running loss: 0.01495
# Saving the new running checkpoint
# [15,  7800] running loss: 0.01499
# Saving the new running checkpoint
# [15,  8000] running loss: 0.01505
# Saving the new running checkpoint
# [15,  8200] running loss: 0.01506
# Saving the new running checkpoint
# [15,  8400] running loss: 0.01512
# Saving the new running checkpoint
# [15,  8600] running loss: 0.01506
# Saving the new running checkpoint
# [15,  8800] running loss: 0.01499
# Saving the new running checkpoint
# [15,  9000] running loss: 0.01496
# Saving the new running checkpoint
# [15,  9200] running loss: 0.01493
# Saving the new running checkpoint
# [15,  9400] running loss: 0.01500
# Saving the new running checkpoint
# [15,  9600] running loss: 0.01511
# Saving the new running checkpoint
# [15,  9800] running loss: 0.01503
# Saving the new running checkpoint
# [15, 10000] running loss: 0.01514
# Saving the new running checkpoint
# [15, 10200] running loss: 0.01501
# Saving the new running checkpoint
# [15, 10400] running loss: 0.01506
# Saving the new running checkpoint
# [15, 10600] running loss: 0.01496
# Saving the new running checkpoint
# [15, 10800] running loss: 0.01508
# Saving the new running checkpoint
# [15, 11000] running loss: 0.01502
# Saving the new running checkpoint
# [15, 11200] running loss: 0.01500
# Saving the new running checkpoint
# [15, 11400] running loss: 0.01501
# Saving the new running checkpoint
# [15, 11600] running loss: 0.01506
# Saving the new running checkpoint
# [15, 11800] running loss: 0.01494
# Saving the new running checkpoint
# [15, 12000] running loss: 0.01493
# Saving the new running checkpoint
# [15, 12200] running loss: 0.01502
# Saving the new running checkpoint
# [15, 12400] running loss: 0.01504
# Saving the new running checkpoint
# [15, 12600] running loss: 0.01502
# Saving the new running checkpoint
# [15, 12800] running loss: 0.01502
# Saving the new running checkpoint
# [15, 13000] running loss: 0.01501
# Saving the new running checkpoint
# [15, 13200] running loss: 0.01497
# Saving the new running checkpoint
# [15, 13400] running loss: 0.01500
# Saving the new running checkpoint
# [15, 13600] running loss: 0.01499
# Saving the new running checkpoint
# [15, 13800] running loss: 0.01501
# Saving the new running checkpoint
# [15, 14000] running loss: 0.01501
# Saving the new running checkpoint
# Training loss for epoch 15: 0.00012
# Start validation for epoch 15
# Validation loss for epoch 15: 0.00012
# Saving the new best checkpoint
# Saving the checkpoint for epoch 15
# Start training for epoch 16
# [16,   200] running loss: 0.01492
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [16,   400] running loss: 0.01488
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [16,   600] running loss: 0.01503
# Saving the new running checkpoint
# [16,   800] running loss: 0.01492
# Saving the new running checkpoint
# [16,  1000] running loss: 0.01498
# Saving the new running checkpoint
# [16,  1200] running loss: 0.01490
# Saving the new running checkpoint
# [16,  1400] running loss: 0.01500
# Saving the new running checkpoint
# [16,  1600] running loss: 0.01485
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [16,  1800] running loss: 0.01491
# Saving the new running checkpoint
# [16,  2000] running loss: 0.01489
# Saving the new running checkpoint
# [16,  2200] running loss: 0.01480
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [16,  2400] running loss: 0.01488
# Saving the new running checkpoint
# [16,  2600] running loss: 0.01499
# Saving the new running checkpoint
# [16,  2800] running loss: 0.01495
# Saving the new running checkpoint
# [16,  3000] running loss: 0.01490
# Saving the new running checkpoint
# [16,  3200] running loss: 0.01494
# Saving the new running checkpoint
# [16,  3400] running loss: 0.01492
# Saving the new running checkpoint
# [16,  3600] running loss: 0.01498
# Saving the new running checkpoint
# [16,  3800] running loss: 0.01499
# Saving the new running checkpoint
# [16,  4000] running loss: 0.01485
# Saving the new running checkpoint
# [16,  4200] running loss: 0.01495
# Saving the new running checkpoint
# [16,  4400] running loss: 0.01494
# Saving the new running checkpoint
# [16,  4600] running loss: 0.01499
# Saving the new running checkpoint
# [16,  4800] running loss: 0.01491
# Saving the new running checkpoint
# [16,  5000] running loss: 0.01492
# Saving the new running checkpoint
# [16,  5200] running loss: 0.01493
# Saving the new running checkpoint
# [16,  5400] running loss: 0.01497
# Saving the new running checkpoint
# [16,  5600] running loss: 0.01494
# Saving the new running checkpoint
# [16,  5800] running loss: 0.01497
# Saving the new running checkpoint
# [16,  6000] running loss: 0.01490
# Saving the new running checkpoint
# [16,  6200] running loss: 0.01495
# Saving the new running checkpoint
# [16,  6400] running loss: 0.01487
# Saving the new running checkpoint
# [16,  6600] running loss: 0.01494
# Saving the new running checkpoint
# [16,  6800] running loss: 0.01489
# Saving the new running checkpoint
# [16,  7000] running loss: 0.01491
# Saving the new running checkpoint
# [16,  7200] running loss: 0.01493
# Saving the new running checkpoint
# [16,  7400] running loss: 0.01482
# Saving the new running checkpoint
# [16,  7600] running loss: 0.01488
# Saving the new running checkpoint
# [16,  7800] running loss: 0.01494
# Saving the new running checkpoint
# [16,  8000] running loss: 0.01494
# Saving the new running checkpoint
# [16,  8200] running loss: 0.01489
# Saving the new running checkpoint
# [16,  8400] running loss: 0.01498
# Saving the new running checkpoint
# [16,  8600] running loss: 0.01500
# Saving the new running checkpoint
# [16,  8800] running loss: 0.01492
# Saving the new running checkpoint
# [16,  9000] running loss: 0.01505
# Saving the new running checkpoint
# [16,  9200] running loss: 0.01485
# Saving the new running checkpoint
# [16,  9400] running loss: 0.01499
# Saving the new running checkpoint
# [16,  9600] running loss: 0.01485
# Saving the new running checkpoint
# [16,  9800] running loss: 0.01491
# Saving the new running checkpoint
# [16, 10000] running loss: 0.01490
# Saving the new running checkpoint
# [16, 10200] running loss: 0.01489
# Saving the new running checkpoint
# [16, 10400] running loss: 0.01491
# Saving the new running checkpoint
# [16, 10600] running loss: 0.01493
# Saving the new running checkpoint
# [16, 10800] running loss: 0.01480
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [16, 11000] running loss: 0.01498
# Saving the new running checkpoint
# [16, 11200] running loss: 0.01492
# Saving the new running checkpoint
# [16, 11400] running loss: 0.01496
# Saving the new running checkpoint
# [16, 11600] running loss: 0.01498
# Saving the new running checkpoint
# [16, 11800] running loss: 0.01495
# Saving the new running checkpoint
# [16, 12000] running loss: 0.01489
# Saving the new running checkpoint
# [16, 12200] running loss: 0.01496
# Saving the new running checkpoint
# [16, 12400] running loss: 0.01482
# Saving the new running checkpoint
# [16, 12600] running loss: 0.01489
# Saving the new running checkpoint
# [16, 12800] running loss: 0.01486
# Saving the new running checkpoint
# [16, 13000] running loss: 0.01490
# Saving the new running checkpoint
# [16, 13200] running loss: 0.01491
# Saving the new running checkpoint
# [16, 13400] running loss: 0.01492
# Saving the new running checkpoint
# [16, 13600] running loss: 0.01484
# Saving the new running checkpoint
# [16, 13800] running loss: 0.01499
# Saving the new running checkpoint
# [16, 14000] running loss: 0.01496
# Saving the new running checkpoint
# Training loss for epoch 16: 0.00012
# Start validation for epoch 16
# Validation loss for epoch 16: 0.00012
# Saving the checkpoint for epoch 16
# Start training for epoch 17
# [17,   200] running loss: 0.01478
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [17,   400] running loss: 0.01484
# Saving the new running checkpoint
# [17,   600] running loss: 0.01485
# Saving the new running checkpoint
# [17,   800] running loss: 0.01475
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [17,  1000] running loss: 0.01483
# Saving the new running checkpoint
# [17,  1200] running loss: 0.01495
# Saving the new running checkpoint
# [17,  1400] running loss: 0.01481
# Saving the new running checkpoint
# [17,  1600] running loss: 0.01473
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [17,  1800] running loss: 0.01472
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [17,  2000] running loss: 0.01486
# Saving the new running checkpoint
# [17,  2200] running loss: 0.01483
# Saving the new running checkpoint
# [17,  2400] running loss: 0.01481
# Saving the new running checkpoint
# [17,  2600] running loss: 0.01479
# Saving the new running checkpoint
# [17,  2800] running loss: 0.01486
# Saving the new running checkpoint
# [17,  3000] running loss: 0.01479
# Saving the new running checkpoint
# [17,  3200] running loss: 0.01484
# Saving the new running checkpoint
# [17,  3400] running loss: 0.01471
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [17,  3600] running loss: 0.01490
# Saving the new running checkpoint
# [17,  3800] running loss: 0.01482
# Saving the new running checkpoint
# [17,  4000] running loss: 0.01488
# Saving the new running checkpoint
# [17,  4200] running loss: 0.01478
# Saving the new running checkpoint
# [17,  4400] running loss: 0.01484
# Saving the new running checkpoint
# [17,  4600] running loss: 0.01483
# Saving the new running checkpoint
# [17,  4800] running loss: 0.01487
# Saving the new running checkpoint
# [17,  5000] running loss: 0.01481
# Saving the new running checkpoint
# [17,  5200] running loss: 0.01485
# Saving the new running checkpoint
# [17,  5400] running loss: 0.01486
# Saving the new running checkpoint
# [17,  5600] running loss: 0.01465
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [17,  5800] running loss: 0.01479
# Saving the new running checkpoint
# [17,  6000] running loss: 0.01482
# Saving the new running checkpoint
# [17,  6200] running loss: 0.01481
# Saving the new running checkpoint
# [17,  6400] running loss: 0.01482
# Saving the new running checkpoint
# [17,  6600] running loss: 0.01482
# Saving the new running checkpoint
# [17,  6800] running loss: 0.01481
# Saving the new running checkpoint
# [17,  7000] running loss: 0.01483
# Saving the new running checkpoint
# [17,  7200] running loss: 0.01484
# Saving the new running checkpoint
# [17,  7400] running loss: 0.01484
# Saving the new running checkpoint
# [17,  7600] running loss: 0.01485
# Saving the new running checkpoint
# [17,  7800] running loss: 0.01482
# Saving the new running checkpoint
# [17,  8000] running loss: 0.01478
# Saving the new running checkpoint
# [17,  8200] running loss: 0.01486
# Saving the new running checkpoint
# [17,  8400] running loss: 0.01495
# Saving the new running checkpoint
# [17,  8600] running loss: 0.01471
# Saving the new running checkpoint
# [17,  8800] running loss: 0.01476
# Saving the new running checkpoint
# [17,  9000] running loss: 0.01480
# Saving the new running checkpoint
# [17,  9200] running loss: 0.01477
# Saving the new running checkpoint
# [17,  9400] running loss: 0.01481
# Saving the new running checkpoint
# [17,  9600] running loss: 0.01484
# Saving the new running checkpoint
# [17,  9800] running loss: 0.01483
# Saving the new running checkpoint
# [17, 10000] running loss: 0.01477
# Saving the new running checkpoint
# [17, 10200] running loss: 0.01487
# Saving the new running checkpoint
# [17, 10400] running loss: 0.01478
# Saving the new running checkpoint
# [17, 10600] running loss: 0.01478
# Saving the new running checkpoint
# [17, 10800] running loss: 0.01492
# Saving the new running checkpoint
# [17, 11000] running loss: 0.01480
# Saving the new running checkpoint
# [17, 11200] running loss: 0.01479
# Saving the new running checkpoint
# [17, 11400] running loss: 0.01469
# Saving the new running checkpoint
# [17, 11600] running loss: 0.01490
# Saving the new running checkpoint
# [17, 11800] running loss: 0.01489
# Saving the new running checkpoint
# [17, 12000] running loss: 0.01485
# Saving the new running checkpoint
# [17, 12200] running loss: 0.01480
# Saving the new running checkpoint
# [17, 12400] running loss: 0.01480
# Saving the new running checkpoint
# [17, 12600] running loss: 0.01486
# Saving the new running checkpoint
# [17, 12800] running loss: 0.01487
# Saving the new running checkpoint
# [17, 13000] running loss: 0.01489
# Saving the new running checkpoint
# [17, 13200] running loss: 0.01488
# Saving the new running checkpoint
# [17, 13400] running loss: 0.01482
# Saving the new running checkpoint
# [17, 13600] running loss: 0.01478
# Saving the new running checkpoint
# [17, 13800] running loss: 0.01480
# Saving the new running checkpoint
# [17, 14000] running loss: 0.01483
# Saving the new running checkpoint
# Training loss for epoch 17: 0.00012
# Start validation for epoch 17
# Validation loss for epoch 17: 0.00012
# Saving the checkpoint for epoch 17
# Start training for epoch 18
# [18,   200] running loss: 0.01473
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [18,   400] running loss: 0.01468
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [18,   600] running loss: 0.01477
# Saving the new running checkpoint
# [18,   800] running loss: 0.01474
# Saving the new running checkpoint
# [18,  1000] running loss: 0.01470
# Saving the new running checkpoint
# [18,  1200] running loss: 0.01469
# Saving the new running checkpoint
# [18,  1400] running loss: 0.01471
# Saving the new running checkpoint
# [18,  1600] running loss: 0.01476
# Saving the new running checkpoint
# [18,  1800] running loss: 0.01468
# Saving the new running checkpoint
# [18,  2000] running loss: 0.01467
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [18,  2200] running loss: 0.01473
# Saving the new running checkpoint
# [18,  2400] running loss: 0.01473
# Saving the new running checkpoint
# [18,  2600] running loss: 0.01463
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [18,  2800] running loss: 0.01473
# Saving the new running checkpoint
# [18,  3000] running loss: 0.01467
# Saving the new running checkpoint
# [18,  3200] running loss: 0.01471
# Saving the new running checkpoint
# [18,  3400] running loss: 0.01477
# Saving the new running checkpoint
# [18,  3600] running loss: 0.01471
# Saving the new running checkpoint
# [18,  3800] running loss: 0.01478
# Saving the new running checkpoint
# [18,  4000] running loss: 0.01480
# Saving the new running checkpoint
# [18,  4200] running loss: 0.01473
# Saving the new running checkpoint
# [18,  4400] running loss: 0.01472
# Saving the new running checkpoint
# [18,  4600] running loss: 0.01473
# Saving the new running checkpoint
# [18,  4800] running loss: 0.01473
# Saving the new running checkpoint
# [18,  5000] running loss: 0.01472
# Saving the new running checkpoint
# [18,  5200] running loss: 0.01463
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [18,  5400] running loss: 0.01473
# Saving the new running checkpoint
# [18,  5600] running loss: 0.01473
# Saving the new running checkpoint
# [18,  5800] running loss: 0.01463
# Saving the new running checkpoint
# [18,  6000] running loss: 0.01470
# Saving the new running checkpoint
# [18,  6200] running loss: 0.01468
# Saving the new running checkpoint
# [18,  6400] running loss: 0.01475
# Saving the new running checkpoint
# [18,  6600] running loss: 0.01471
# Saving the new running checkpoint
# [18,  6800] running loss: 0.01473
# Saving the new running checkpoint
# [18,  7000] running loss: 0.01466
# Saving the new running checkpoint
# [18,  7200] running loss: 0.01468
# Saving the new running checkpoint
# [18,  7400] running loss: 0.01469
# Saving the new running checkpoint
# [18,  7600] running loss: 0.01478
# Saving the new running checkpoint
# [18,  7800] running loss: 0.01478
# Saving the new running checkpoint
# [18,  8000] running loss: 0.01476
# Saving the new running checkpoint
# [18,  8200] running loss: 0.01475
# Saving the new running checkpoint
# [18,  8400] running loss: 0.01462
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [18,  8600] running loss: 0.01477
# Saving the new running checkpoint
# [18,  8800] running loss: 0.01471
# Saving the new running checkpoint
# [18,  9000] running loss: 0.01466
# Saving the new running checkpoint
# [18,  9200] running loss: 0.01478
# Saving the new running checkpoint
# [18,  9400] running loss: 0.01466
# Saving the new running checkpoint
# [18,  9600] running loss: 0.01479
# Saving the new running checkpoint
# [18,  9800] running loss: 0.01474
# Saving the new running checkpoint
# [18, 10000] running loss: 0.01474
# Saving the new running checkpoint
# [18, 10200] running loss: 0.01474
# Saving the new running checkpoint
# [18, 10400] running loss: 0.01476
# Saving the new running checkpoint
# [18, 10600] running loss: 0.01467
# Saving the new running checkpoint
# [18, 10800] running loss: 0.01475
# Saving the new running checkpoint
# [18, 11000] running loss: 0.01480
# Saving the new running checkpoint
# [18, 11200] running loss: 0.01465
# Saving the new running checkpoint
# [18, 11400] running loss: 0.01472
# Saving the new running checkpoint
# [18, 11600] running loss: 0.01473
# Saving the new running checkpoint
# [18, 11800] running loss: 0.01478
# Saving the new running checkpoint
# [18, 12000] running loss: 0.01473
# Saving the new running checkpoint
# [18, 12200] running loss: 0.01486
# Saving the new running checkpoint
# [18, 12400] running loss: 0.01467
# Saving the new running checkpoint
# [18, 12600] running loss: 0.01465
# Saving the new running checkpoint
# [18, 12800] running loss: 0.01468
# Saving the new running checkpoint
# [18, 13000] running loss: 0.01468
# Saving the new running checkpoint
# [18, 13200] running loss: 0.01470
# Saving the new running checkpoint
# [18, 13400] running loss: 0.01470
# Saving the new running checkpoint
# [18, 13600] running loss: 0.01463
# Saving the new running checkpoint
# [18, 13800] running loss: 0.01482
# Saving the new running checkpoint
# [18, 14000] running loss: 0.01472
# Saving the new running checkpoint
# Training loss for epoch 18: 0.00011
# Start validation for epoch 18
# Validation loss for epoch 18: 0.00012
# Saving the checkpoint for epoch 18
# Start training for epoch 19
# [19,   200] running loss: 0.01469
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [19,   400] running loss: 0.01462
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [19,   600] running loss: 0.01460
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [19,   800] running loss: 0.01463
# Saving the new running checkpoint
# [19,  1000] running loss: 0.01466
# Saving the new running checkpoint
# [19,  1200] running loss: 0.01464
# Saving the new running checkpoint
# [19,  1400] running loss: 0.01456
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [19,  1600] running loss: 0.01464
# Saving the new running checkpoint
# [19,  1800] running loss: 0.01461
# Saving the new running checkpoint
# [19,  2000] running loss: 0.01461
# Saving the new running checkpoint
# [19,  2200] running loss: 0.01455
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [19,  2400] running loss: 0.01467
# Saving the new running checkpoint
# [19,  2600] running loss: 0.01468
# Saving the new running checkpoint
# [19,  2800] running loss: 0.01459
# Saving the new running checkpoint
# [19,  3000] running loss: 0.01457
# Saving the new running checkpoint
# [19,  3200] running loss: 0.01470
# Saving the new running checkpoint
# [19,  3400] running loss: 0.01473
# Saving the new running checkpoint
# [19,  3600] running loss: 0.01461
# Saving the new running checkpoint
# [19,  3800] running loss: 0.01470
# Saving the new running checkpoint
# [19,  4000] running loss: 0.01463
# Saving the new running checkpoint
# [19,  4200] running loss: 0.01462
# Saving the new running checkpoint
# [19,  4400] running loss: 0.01467
# Saving the new running checkpoint
# [19,  4600] running loss: 0.01460
# Saving the new running checkpoint
# [19,  4800] running loss: 0.01469
# Saving the new running checkpoint
# [19,  5000] running loss: 0.01465
# Saving the new running checkpoint
# [19,  5200] running loss: 0.01464
# Saving the new running checkpoint
# [19,  5400] running loss: 0.01462
# Saving the new running checkpoint
# [19,  5600] running loss: 0.01459
# Saving the new running checkpoint
# [19,  5800] running loss: 0.01463
# Saving the new running checkpoint
# [19,  6000] running loss: 0.01457
# Saving the new running checkpoint
# [19,  6200] running loss: 0.01467
# Saving the new running checkpoint
# [19,  6400] running loss: 0.01463
# Saving the new running checkpoint
# [19,  6600] running loss: 0.01466
# Saving the new running checkpoint
# [19,  6800] running loss: 0.01461
# Saving the new running checkpoint
# [19,  7000] running loss: 0.01462
# Saving the new running checkpoint
# [19,  7200] running loss: 0.01463
# Saving the new running checkpoint
# [19,  7400] running loss: 0.01465
# Saving the new running checkpoint
# [19,  7600] running loss: 0.01472
# Saving the new running checkpoint
# [19,  7800] running loss: 0.01454
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [19,  8000] running loss: 0.01463
# Saving the new running checkpoint
# [19,  8200] running loss: 0.01469
# Saving the new running checkpoint
# [19,  8400] running loss: 0.01461
# Saving the new running checkpoint
# [19,  8600] running loss: 0.01456
# Saving the new running checkpoint
# [19,  8800] running loss: 0.01467
# Saving the new running checkpoint
# [19,  9000] running loss: 0.01463
# Saving the new running checkpoint
# [19,  9200] running loss: 0.01466
# Saving the new running checkpoint
# [19,  9400] running loss: 0.01459
# Saving the new running checkpoint
# [19,  9600] running loss: 0.01461
# Saving the new running checkpoint
# [19,  9800] running loss: 0.01461
# Saving the new running checkpoint
# [19, 10000] running loss: 0.01462
# Saving the new running checkpoint
# [19, 10200] running loss: 0.01470
# Saving the new running checkpoint
# [19, 10400] running loss: 0.01458
# Saving the new running checkpoint
# [19, 10600] running loss: 0.01453
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [19, 10800] running loss: 0.01460
# Saving the new running checkpoint
# [19, 11000] running loss: 0.01467
# Saving the new running checkpoint
# [19, 11200] running loss: 0.01465
# Saving the new running checkpoint
# [19, 11400] running loss: 0.01451
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [19, 11600] running loss: 0.01467
# Saving the new running checkpoint
# [19, 11800] running loss: 0.01461
# Saving the new running checkpoint
# [19, 12000] running loss: 0.01467
# Saving the new running checkpoint
# [19, 12200] running loss: 0.01469
# Saving the new running checkpoint
# [19, 12400] running loss: 0.01465
# Saving the new running checkpoint
# [19, 12600] running loss: 0.01455
# Saving the new running checkpoint
# [19, 12800] running loss: 0.01469
# Saving the new running checkpoint
# [19, 13000] running loss: 0.01458
# Saving the new running checkpoint
# [19, 13200] running loss: 0.01469
# Saving the new running checkpoint
# [19, 13400] running loss: 0.01459
# Saving the new running checkpoint
# [19, 13600] running loss: 0.01462
# Saving the new running checkpoint
# [19, 13800] running loss: 0.01464
# Saving the new running checkpoint
# [19, 14000] running loss: 0.01458
# Saving the new running checkpoint
# Training loss for epoch 19: 0.00011
# Start validation for epoch 19
# Validation loss for epoch 19: 0.00012
# Saving the new best checkpoint
# Saving the checkpoint for epoch 19
# Start training for epoch 20
# [20,   200] running loss: 0.01447
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [20,   400] running loss: 0.01459
# Saving the new running checkpoint
# [20,   600] running loss: 0.01454
# Saving the new running checkpoint
# [20,   800] running loss: 0.01445
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [20,  1000] running loss: 0.01450
# Saving the new running checkpoint
# [20,  1200] running loss: 0.01443
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [20,  1400] running loss: 0.01454
# Saving the new running checkpoint
# [20,  1600] running loss: 0.01452
# Saving the new running checkpoint
# [20,  1800] running loss: 0.01455
# Saving the new running checkpoint
# [20,  2000] running loss: 0.01450
# Saving the new running checkpoint
# [20,  2200] running loss: 0.01456
# Saving the new running checkpoint
# [20,  2400] running loss: 0.01456
# Saving the new running checkpoint
# [20,  2600] running loss: 0.01453
# Saving the new running checkpoint
# [20,  2800] running loss: 0.01449
# Saving the new running checkpoint
# [20,  3000] running loss: 0.01462
# Saving the new running checkpoint
# [20,  3200] running loss: 0.01447
# Saving the new running checkpoint
# [20,  3400] running loss: 0.01455
# Saving the new running checkpoint
# [20,  3600] running loss: 0.01442
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [20,  3800] running loss: 0.01456
# Saving the new running checkpoint
# [20,  4000] running loss: 0.01447
# Saving the new running checkpoint
# [20,  4200] running loss: 0.01464
# Saving the new running checkpoint
# [20,  4400] running loss: 0.01465
# Saving the new running checkpoint
# [20,  4600] running loss: 0.01456
# Saving the new running checkpoint
# [20,  4800] running loss: 0.01455
# Saving the new running checkpoint
# [20,  5000] running loss: 0.01454
# Saving the new running checkpoint
# [20,  5200] running loss: 0.01454
# Saving the new running checkpoint
# [20,  5400] running loss: 0.01454
# Saving the new running checkpoint
# [20,  5600] running loss: 0.01456
# Saving the new running checkpoint
# [20,  5800] running loss: 0.01452
# Saving the new running checkpoint
# [20,  6000] running loss: 0.01451
# Saving the new running checkpoint
# [20,  6200] running loss: 0.01460
# Saving the new running checkpoint
# [20,  6400] running loss: 0.01464
# Saving the new running checkpoint
# [20,  6600] running loss: 0.01458
# Saving the new running checkpoint
# [20,  6800] running loss: 0.01460
# Saving the new running checkpoint
# [20,  7000] running loss: 0.01455
# Saving the new running checkpoint
# [20,  7200] running loss: 0.01452
# Saving the new running checkpoint
# [20,  7400] running loss: 0.01449
# Saving the new running checkpoint
# [20,  7600] running loss: 0.01461
# Saving the new running checkpoint
# [20,  7800] running loss: 0.01447
# Saving the new running checkpoint
# [20,  8000] running loss: 0.01459
# Saving the new running checkpoint
# [20,  8200] running loss: 0.01461
# Saving the new running checkpoint
# [20,  8400] running loss: 0.01460
# Saving the new running checkpoint
# [20,  8600] running loss: 0.01448
# Saving the new running checkpoint
# [20,  8800] running loss: 0.01455
# Saving the new running checkpoint
# [20,  9000] running loss: 0.01461
# Saving the new running checkpoint
# [20,  9200] running loss: 0.01452
# Saving the new running checkpoint
# [20,  9400] running loss: 0.01447
# Saving the new running checkpoint
# [20,  9600] running loss: 0.01454
# Saving the new running checkpoint
# [20,  9800] running loss: 0.01461
# Saving the new running checkpoint
# [20, 10000] running loss: 0.01469
# Saving the new running checkpoint
# [20, 10200] running loss: 0.01455
# Saving the new running checkpoint
# [20, 10400] running loss: 0.01451
# Saving the new running checkpoint
# [20, 10600] running loss: 0.01459
# Saving the new running checkpoint
# [20, 10800] running loss: 0.01455
# Saving the new running checkpoint
# [20, 11000] running loss: 0.01453
# Saving the new running checkpoint
# [20, 11200] running loss: 0.01445
# Saving the new running checkpoint
# [20, 11400] running loss: 0.01458
# Saving the new running checkpoint
# [20, 11600] running loss: 0.01462
# Saving the new running checkpoint
# [20, 11800] running loss: 0.01449
# Saving the new running checkpoint
# [20, 12000] running loss: 0.01453
# Saving the new running checkpoint
# [20, 12200] running loss: 0.01453
# Saving the new running checkpoint
# [20, 12400] running loss: 0.01451
# Saving the new running checkpoint
# [20, 12600] running loss: 0.01442
# Saving the new best running checkpoint
# Saving the new running checkpoint
# [20, 12800] running loss: 0.01458
# Saving the new running checkpoint
# [20, 13000] running loss: 0.01457
# Saving the new running checkpoint
# [20, 13200] running loss: 0.01464
# Saving the new running checkpoint
# [20, 13400] running loss: 0.01461
# Saving the new running checkpoint
# [20, 13600] running loss: 0.01454
# Saving the new running checkpoint
# [20, 13800] running loss: 0.01462
# Saving the new running checkpoint
# [20, 14000] running loss: 0.01464
# Saving the new running checkpoint
# Training loss for epoch 20: 0.00011
# Start validation for epoch 20
# Validation loss for epoch 20: 0.00012
# Saving the new best checkpoint
# Saving the checkpoint for epoch 20
